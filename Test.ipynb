# %%
def mb():
    mbalance=3200000
    return mbalance

# %%
def total():
    a= mb()
    addie=int(input("Enter The Amount"))
    total=a+addie
    print("Total:",total)
total()

# %%
def widrawal():
    a=mb()
    addie=int(input("Enter The Amount"))
    total=a-addie
    print("Remaining",total)
widrawal()

# %%
def banking():
                print("Banking system")
                print("1.check balance")
                print("2.diposit amount")
                print("3.widrawal amount")
                print("4.Exit")
while True:
        select=input("Enter the service number")
        if select in ["4"]:
                print("Thank you for using our banking system.")
                break
        elif select in ["1","2","3"]:
                if select=="1":
                        print(mb())
                elif select=="2":
                        total()
                elif select=="3":
                        widrawal()
        else:
                print("Enter Number Between 1-4")
